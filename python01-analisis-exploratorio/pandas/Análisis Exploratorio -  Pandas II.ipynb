# %% [markdown]
# Librerías a instalar desde la línea de comando
#
# pip install -U scikit-learn
#
# pip install pandas
#
# ¿Cómo chequeo la instalación desde la línea de comando de windows?
#
# pip list
#
# Librerías a instalar si estoy desde Anaconda
#
# conda install scikit-learn
#
# conda install pandas
#
# conda install pandas=0.20.3
#
# ¿Cómo chequeo las librerias instaladas de Anaconda?
#
# conda list

# %%
import os
import pandas as pd
#import numpy as npdiabetes
import matplotlib.pyplot as plt
os.getcwd()
#os.chdir('\')
diabetes = pd.read_csv("diabetes.csv")

# %%
diabetes.head(20)
#Por Defecto me muestra 5 filas - Puedo cambiarlo pasando como parámetro la cantidad
# Out:
#     Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0           6      148                72                        35
# 1           1       85                66                        29
# 2           8      183                64                         0
# 3           1       89                66                        23
# 4           0      137                40                        35
# 5           5      116                74                         0
# 6           3       78                50                        32
# 7          10      115                 0                         0
# 8           2      197                70                        45
# 9           8      125                96                         0
# 10          4      110                92                         0
# 11         10      168                74                         0
# 12         10      139                80                         0
# 13          1      189                60                        23
# 14          5      166                72                        19
# 15          7      100                 0                         0
# 16          0      118                84                        47
# 17          7      107                74                         0
# 18          1      103                30                        38
# 19          1      115                70                        30
#
#      InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 0                       0                   33.6                        0.627
# 1                       0                   26.6                        0.351
# 2                       0                   23.3                        0.672
# 3                      94                   28.1                        0.167
# 4                     168                   43.1                        2.288
# 5                       0                   25.6                        0.201
# 6                      88                   31.0                        0.248
# 7                       0                   35.3                        0.134
# 8                     543                   30.5                        0.158
# 9                       0                    0.0                        0.232
# 10                      0                   37.6                        0.191
# 11                      0                   38.0                        0.537
# 12                      0                   27.1                        1.441
# 13                    846                   30.1                        0.398
# 14                    175                   25.8                        0.587
# 15                      0                   30.0                        0.484
# 16                    230                   45.8                        0.551
# 17                      0                   29.6                        0.254
# 18                     83                   43.3                        0.183
# 19                     96                   34.6                        0.529
#
#      Edad  Clase
# 0      50      1
# 1      31      0
# 2      32      1
# 3      21      0
# 4      33      1
# 5      30      0
# 6      26      1
# 7      29      0
# 8      53      1
# 9      54      1
# 10     30      0
# 11     34      1
# 12     57      0
# 13     59      1
# 14     51      1
# 15     32      1
# 16     31      1
# 17     31      1
# 18     33      0
# 19     32      1

# %%
os.getcwd()
# Out:
# 'C:\\Users\\susan'

# %%
diabetes.head(10)
# Out:
#    Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0          6      148                72                        35
# 1          1       85                66                        29
# 2          8      183                64                         0
# 3          1       89                66                        23
# 4          0      137                40                        35
# 5          5      116                74                         0
# 6          3       78                50                        32
# 7         10      115                 0                         0
# 8          2      197                70                        45
# 9          8      125                96                         0
#
#     InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 0                      0                   33.6                        0.627
# 1                      0                   26.6                        0.351
# 2                      0                   23.3                        0.672
# 3                     94                   28.1                        0.167
# 4                    168                   43.1                        2.288
# 5                      0                   25.6                        0.201
# 6                     88                   31.0                        0.248
# 7                      0                   35.3                        0.134
# 8                    543                   30.5                        0.158
# 9                      0                    0.0                        0.232
#
#     Edad  Clase
# 0     50      1
# 1     31      0
# 2     32      1
# 3     21      0
# 4     33      1
# 5     30      0
# 6     26      1
# 7     29      0
# 8     53      1
# 9     54      1

# %%
len(diabetes.Embarazos.value_counts())
# Out:
# 17

# %%
diabetes.columns
# Out:
# Index(['Embarazos', 'Glucosa', 'Presión Arterial', ' GrosorDePliegueDelaPiel',
#        ' InsulinaSéricaDe2HRS', ' ÍndiceDeMasaCorporal',
#        ' FunciónDePedigríDeDiabetes', ' Edad', 'Clase'],
#       dtype='object')

# %%
diabetes.Embarazos.nunique()
# Out:
# 17

# %%
diabetes.nunique()
# Out:
# Embarazos                       17
# Glucosa                        136
# Presión Arterial                47
#  GrosorDePliegueDelaPiel        51
#  InsulinaSéricaDe2HRS          186
#  ÍndiceDeMasaCorporal          248
#  FunciónDePedigríDeDiabetes    517
#  Edad                           52
# Clase                            2
# dtype: int64

# %%
diabetes.describe()
# Out:
#         Embarazos     Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# count  768.000000  768.000000        768.000000                768.000000
# mean     3.845052  120.894531         69.105469                 20.536458
# std      3.369578   31.972618         19.355807                 15.952218
# min      0.000000    0.000000          0.000000                  0.000000
# 25%      1.000000   99.000000         62.000000                  0.000000
# 50%      3.000000  117.000000         72.000000                 23.000000
# 75%      6.000000  140.250000         80.000000                 32.000000
# max     17.000000  199.000000        122.000000                 99.000000
#
#         InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal  \
# count             768.000000             768.000000
# mean               79.799479              31.992578
# std               115.244002               7.884160
# min                 0.000000               0.000000
# 25%                 0.000000              27.300000
# 50%                30.500000              32.000000
# 75%               127.250000              36.600000
# max               846.000000              67.100000
#
#         FunciónDePedigríDeDiabetes        Edad       Clase
# count                   768.000000  768.000000  768.000000
# mean                      0.471876   33.240885    0.348958
# std                       0.331329   11.760232    0.476951
# min                       0.078000   21.000000    0.000000
# 25%                       0.243750   24.000000    0.000000
# 50%                       0.372500   29.000000    0.000000
# 75%                       0.626250   41.000000    1.000000
# max                       2.420000   81.000000    1.000000

# %%
diabetes.isna().any()
# Out:
# Embarazos                      False
# Glucosa                        False
# Presión Arterial               False
#  GrosorDePliegueDelaPiel       False
#  InsulinaSéricaDe2HRS          False
#  ÍndiceDeMasaCorporal          False
#  FunciónDePedigríDeDiabetes    False
#  Edad                          False
# Clase                          False
# dtype: bool

# %%
diabetes[['Clase','Glucosa']].groupby('Clase').sum()
diabetes[['Clase','Glucosa']].groupby('Clase').mean()
diabetes[['Clase','Glucosa']].groupby('Clase').size().plot(kind='bar')

# %%
diabetes.dtypes
# Out:
# Embarazos                        int64
# Glucosa                          int64
# Presión Arterial                 int64
#  GrosorDePliegueDelaPiel         int64
#  InsulinaSéricaDe2HRS            int64
#  ÍndiceDeMasaCorporal          float64
#  FunciónDePedigríDeDiabetes    float64
#  Edad                            int64
# Clase                            int64
# dtype: object

# %%
diabetes.Glucosa = diabetes.Glucosa.astype('int64')

# %%
diabetes.dtypes
# Out:
# Embarazos                        int64
# Glucosa                          int64
# Presión Arterial                 int64
#  GrosorDePliegueDelaPiel         int64
#  InsulinaSéricaDe2HRS            int64
#  ÍndiceDeMasaCorporal          float64
#  FunciónDePedigríDeDiabetes    float64
#  Edad                            int64
# Clase                            int64
# dtype: object

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.size
# Out:
# 6912

# %%
diabetes.Embarazos
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Embarazos, Length: 768, dtype: int64

# %%
diabetes.isna().any
# Out:
# <bound method DataFrame.any of      Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0        False    False             False                     False
# 1        False    False             False                     False
# 2        False    False             False                     False
# 3        False    False             False                     False
# 4        False    False             False                     False
# ..         ...      ...               ...                       ...
# 763      False    False             False                     False
# 764      False    False             False                     False
# 765      False    False             False                     False
# 766      False    False             False                     False
# 767      False    False             False                     False
#
#       InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal  \
# 0                    False                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                    False                  False
# ..                     ...                    ...
# 763                  False                  False
# 764                  False                  False
# 765                  False                  False
# 766                  False                  False
# 767                  False                  False
#
#       FunciónDePedigríDeDiabetes   Edad  Clase
# 0                          False  False  False
# 1                          False  False  False
# 2                          False  False  False
# 3                          False  False  False
# 4                          False  False  False
# ..                           ...    ...    ...
# 763                        False  False  False
# 764                        False  False  False
# 765                        False  False  False
# 766                        False  False  False
# 767                        False  False  False
#
# [768 rows x 9 columns]>

# %%
diabetes.isna().sum()
# Out:
# Embarazos                      0
# Glucosa                        0
# Presión Arterial               0
#  GrosorDePliegueDelaPiel       0
#  InsulinaSéricaDe2HRS          0
#  ÍndiceDeMasaCorporal          0
#  FunciónDePedigríDeDiabetes    0
#  Edad                          0
# Clase                          0
# dtype: int64

# %%
diabetes[['Clase','Glucosa']].groupby('Clase').mean().sort_values('Clase')
# Out:
#           Glucosa
# Clase
# 0      109.980000
# 1      141.257463

# %%
diabetes[['Clase','Glucosa']].groupby('Clase').mean().sort_values('Clase', ascending=False)
# Out:
#           Glucosa
# Clase
# 1      141.257463
# 0      109.980000

# %%
diabetes[['Clase','Glucosa']].groupby('Clase').mean().sort_values('Clase', ascending=True)
# Out:
#           Glucosa
# Clase
# 0      109.980000
# 1      141.257463

# %%
iris = pd.read_csv("Iris.csv")

# %% [markdown]
# Para movilizarnos en el Dataframe tenemos las funciones iloc y loc
#
# La función loc se puede usar de dos formas diferentes: seleccionar filas o columnas en base a una etiqueta o seleccionar filas
#
# o columnas en base a una condición.-
#
# La función iloc me permite desplazarme por el dataframases una función basada en etiquetas para acceder a los datos de un
#
# índice y / o columna en particular y devuelve todas las entradas almacenadas para ese índice / columna en particular.

# %%
iris.loc[[0,1]]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %% [markdown]
# Ahora si quiero ver una columna específica por ejemplo
#
# ![image.png](attachment:image.png)

# %%
iris.loc[[0,1],["SepalWidthCm","PetalLengthCm"]]
# Out:
#    SepalWidthCm  PetalLengthCm
# 0           3.5            1.4
# 1           3.0            1.4

# %% [markdown]
# Ejercicio:
#
# Obtener las filas desde la 4, 3 y 9 para SepalLengthCm y SepalWidthCm

# %%
iris.loc[[4,3,9],["SepalLengthCm","SepalWidthCm"]]
# Out:
#    SepalLengthCm  SepalWidthCm
# 4            5.0           3.6
# 3            4.6           3.1
# 9            4.9           3.1

# %% [markdown]
# Ejercicio:
#
# Mostrar las filas desde la 1 a la 5

# %%
iris.loc[1:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %% [markdown]
# Ejercicio
#
# Mostrar las filas desde la 1 a la 5 para SepalLengthCm y SepalWidthCm

# %%
iris.loc[[1,5],["SepalLengthCm","SepalWidthCm"]]
# Out:
#    SepalLengthCm  SepalWidthCm
# 1            4.9           3.0
# 5            5.4           3.9

# %%
iris.iloc[1:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris.iloc[0:5] # Primeras cinco filas
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.iloc[:, 0:5] # Primeras cinco columnas
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
iris.iloc[[0,2,1]]  # Primera, tercera y segunda filas
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
iris.iloc[:, [0,2,1]]  # Primera, tercera y segunda columnas
# Out:
#       Id  SepalWidthCm  SepalLengthCm
# 0      1           3.5            5.1
# 1      2           3.0            4.9
# 2      3           3.2            4.7
# 3      4           3.1            4.6
# 4      5           3.6            5.0
# ..   ...           ...            ...
# 145  146           3.0            6.7
# 146  147           2.5            6.3
# 147  148           3.0            6.5
# 148  149           3.4            6.2
# 149  150           3.0            5.9
#
# [150 rows x 3 columns]

# %% [markdown]
# Si quiero filtrar por un valor específico en el dataframe lo puedo hacer de la siguiente manera

# %%
setosa = iris.loc[:, "Species"] == "Iris-setosa"

# %%
df_setosa = iris.loc[setosa]

# %%
df_setosa.head(50)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Combinar Dataframes
#
# Para combinar dataframes tenemos las opciones de merge
#
# ![image.png](attachment:image.png)
#
#
#
# Fusionar para combinar observaciones de diferentes marcos de datos utilizando una variable común como referencia
#
# how = inner
#
# how = outer
#
# how = left
#
# how = right

# %%
df_1 = iris.iloc[[1,51],3:]

# %%
df_1.head()
# Out:
#     PetalLengthCm  PetalWidthCm          Species
# 1             1.4           0.2      Iris-setosa
# 51            4.5           1.5  Iris-versicolor

# %%
df_2 = iris.iloc[[1,51,101],[0,2,4,5]]

# %%
df_2.head()
# Out:
#       Id  SepalWidthCm  PetalWidthCm          Species
# 1      2           3.0           0.2      Iris-setosa
# 51    52           3.2           1.5  Iris-versicolor
# 101  102           2.7           1.9   Iris-virginica

# %%
result = pd.merge(left = df_1 , right = df_2,on= ["Species"], how = "outer")

# %%
result.head()
# Out:
#    PetalLengthCm  PetalWidthCm_x          Species   Id  SepalWidthCm  \
# 0            1.4             0.2      Iris-setosa    2           3.0
# 1            4.5             1.5  Iris-versicolor   52           3.2
# 2            NaN             NaN   Iris-virginica  102           2.7
#
#    PetalWidthCm_y
# 0             0.2
# 1             1.5
# 2             1.9

# %% [markdown]
# Agrupar - Group By

# %%
df_3 = iris.iloc[[1,2,3,4,51,52,53,54],[0,2,4,5]]

# %%
df_3.head()
# Out:
#     Id  SepalWidthCm  PetalWidthCm          Species
# 1    2           3.0           0.2      Iris-setosa
# 2    3           3.2           0.2      Iris-setosa
# 3    4           3.1           0.2      Iris-setosa
# 4    5           3.6           0.2      Iris-setosa
# 51  52           3.2           1.5  Iris-versicolor

# %%
df_3.groupby('PetalWidthCm')

# %%
df_3[['PetalWidthCm','Species']].groupby('Species').sum()
# Out:
#                  PetalWidthCm
# Species
# Iris-setosa               0.8
# Iris-versicolor           5.8

# %%
df_3[['PetalWidthCm','Species']].groupby('Species').mean()
# Out:
#                  PetalWidthCm
# Species
# Iris-setosa              0.20
# Iris-versicolor          1.45

# %%
df_3[['PetalWidthCm','Species']].groupby('Species').count()
# Out:
#                  PetalWidthCm
# Species
# Iris-setosa                 4
# Iris-versicolor             4

# %%
df_4 = iris.iloc[1:5,0:3]

# %%
df_4.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1
# 4   5            5.0           3.6

# %%
df_4["Species"] = ["versicolor", "versicolor", "setosa", "setosa"]

# %%
df_4.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm     Species
# 1   2            4.9           3.0  versicolor
# 2   3            4.7           3.2  versicolor
# 3   4            4.6           3.1      setosa
# 4   5            5.0           3.6      setosa

# %%
df_4.loc[5] = [4.9, 1.4, 1.3, "setosa"]

# %%
df_4.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm     Species
# 1  2.0            4.9           3.0  versicolor
# 2  3.0            4.7           3.2  versicolor
# 3  4.0            4.6           3.1      setosa
# 4  5.0            5.0           3.6      setosa
# 5  4.9            1.4           1.3      setosa

# %% [markdown]
# Vamos a borrar una columna con la función drop
#
# ![image.png](attachment:image.png)

# %%
df_4.drop("Species", axis=1)
# Out:
#     Id  SepalLengthCm  SepalWidthCm
# 1  2.0            4.9           3.0
# 2  3.0            4.7           3.2
# 3  4.0            4.6           3.1
# 4  5.0            5.0           3.6
# 5  4.9            1.4           1.3

# %% [markdown]
# Vamos a borrar una fila
#
# ![image.png](attachment:image.png)

# %%
df_4.drop(2, axis = 0)
# Out:
#     Id  SepalLengthCm  SepalWidthCm     Species
# 1  2.0            4.9           3.0  versicolor
# 3  4.0            4.6           3.1      setosa
# 4  5.0            5.0           3.6      setosa
# 5  4.9            1.4           1.3      setosa

# %% [markdown]
# Podriamos querer concatenar dos dataframes lo podemos hacer con la función concat

# %%
pd.concat([df_4,df_4])
# Out:
#     Id  SepalLengthCm  SepalWidthCm     Species
# 0  2.0            4.9           3.0  versicolor
# 1  3.0            4.7           3.2  versicolor
# 2  4.0            4.6           3.1      setosa
# 3  5.0            5.0           3.6      setosa
# 4  4.9            1.4           1.3      setosa
# 5  2.0            4.9           3.0  versicolor
# 6  3.0            4.7           3.2  versicolor
# 7  4.0            4.6           3.1      setosa
# 8  5.0            5.0           3.6      setosa
# 9  4.9            1.4           1.3      setosa

# %% [markdown]
# Lo que podemos ver que nos conservó los índices, esto podemos corregirlo pasandole como parámetro ignore_index=True
#
# pd.concat([df_4,df_4], ignore_index=True)

# %%
Reestructurar una tabla usando la función pivot

# %%
df = pd.read_excel("Clima.xlsx")

# %%
df.head(10)
# Out:
#          Día        Ciudad  Temperatura
# 0      Lunes  Buenos Aires           15
# 1     Martes  Buenos Aires           20
# 2  Miercoles  Buenos Aires           14
# 3     Jueves  Buenos Aires           10
# 4    Viernes  Buenos Aires            8
# 5      Lunes         Salta           15
# 6     Martes         Salta           25
# 7  Miercoles         Salta           21
# 8     Jueves         Salta           23
# 9    Viernes         Salta           20

# %%
df.pivot(index = "Ciudad", columns= "Día")
# Out:
#              Temperatura
# Día               Jueves Lunes Martes Miercoles Viernes
# Ciudad
# Buenos Aires          10    15     20        14       8
# Salta                 23    15     25        21      20

# %% [markdown]
# Vamos a usar la función melt para cambiar el formato de la tabla

# %%
clima_2 = pd.read_excel("Clima_2.xlsx")

# %%
clima_2.head()
# Out:
#          Día  Buenos Aires  Salta
# 0      Lunes            15     15
# 1     Martes            20     25
# 2  Miercoles            14     21
# 3     Jueves            10     23
# 4    Viernes             8     20

# %%
pd.melt(clima_2, id_vars = ['Día'], var_name = ["Cuidad"], value_name = "Temperatura")
# Out:
#          Día        Cuidad  Temperatura
# 0      Lunes  Buenos Aires           15
# 1     Martes  Buenos Aires           20
# 2  Miercoles  Buenos Aires           14
# 3     Jueves  Buenos Aires           10
# 4    Viernes  Buenos Aires            8
# 5      Lunes         Salta           15
# 6     Martes         Salta           25
# 7  Miercoles         Salta           21
# 8     Jueves         Salta           23
# 9    Viernes         Salta           20
